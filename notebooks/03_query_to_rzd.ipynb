# %%
import requests

# %%
s = requests.Session()

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36 OPR/100.0.0.0',
    'Referer': 'https://ticket.rzd.ru',
    'Host': 'ticket.rzd.ru',
    'Origin': 'https://ticket.rzd.ru',
    'Accept': 'application/json',
    'Accept-Language': 'en-US,en;q=0.9',
    'Content-Type': 'application/json',
}

cookies = {
    'lang': 'ru',
    'AuthFlag': 'false',
    'LANG_SITE': 'ru',
    # 'session-cookie': '17733de2fb1ce28bab8257d51e808458ee142776b8cbe0c6bf4f1956cdaf3dd6b1333f7ce4b92347336085bfdeca204e',
    # 'ClientUid': 'P2EAV6nzkavx8buEqXlAskhtYA6X7KZD',
}

# %%
res = s.post(
    url = 'https://ticket.rzd.ru/apib2b/p/Railway/V1/Search/TrainPricing',
    params = {
        'service_provider': 'B2B_RZD',
    },
    json = {
        "Origin": "2010000",
        "Destination": "2010280",
        "DepartureDate": "2023-07-20T00:00:00",
        "TimeFrom": 0,
        "TimeTo": 24,
        "CarGrouping": "DontGroup",
        "GetByLocalTime": True,
        "SpecialPlacesDemand": "StandardPlacesAndForDisabledPersons"
    },
    headers = headers,
    cookies = cookies,
    allow_redirects = True,
    verify = False,
    timeout = 10,
)
# Out:
# d:\anaconda3\envs\traveler\Lib\site-packages\urllib3\connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ticket.rzd.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
res.json()
# Out:
# {'OriginStationCode': '2010000',
#  'DestinationStationCode': '2010280',
#  'Trains': [{'CarGroups': [{'Carriers': ['ФПК'],
#      'CarrierDisplayNames': ['ФПК'],
#      'ServiceClasses': ['2У'],
#      'MinPrice': 5102.5,
#      'MaxPrice': 7200.1,
#      'CarType': 'Compartment',
#      'CarTypeName': 'КУПЕ',
#      'PlaceQuantity': 0,
#      'LowerPlaceQuantity': 4,
#      'UpperPlaceQuantity': 9,
#      'LowerSidePlaceQuantity': 0,
#      'UpperSidePlaceQuantity': 0,
#      'MalePlaceQuantity': 0,
#      'FemalePlaceQuantity': 0,
#      'EmptyCabinQuantity': 0,
#      'MixedCabinQuantity': 0,
#      'IsSaleForbidden': False,
#      'AvailabilityIndication': 'Available',
#      'CarDescriptions': ['Ж'],
#      'ServiceClassNameRu': None,
#      'ServiceClassNameEn': None,
#      'InternationalServiceClasses': [''],
#      'ServiceCosts': [208.0],
#      'IsBeddingSelectionPossible': False,
#      'BoardingSystemTypes': ['PassengerBoardingControl'],
# ...

# %%
res = s.post(
    url = 'https://ticket.rzd.ru/apib2b/p/Railway/V1/Search/CarPricing',
    params = {
        'service_provider': 'B2B_RZD',
        'isBonusPurchase': False,
    },
    json = {
        "OriginCode": "2010001",
        "DestinationCode": "2010280",
        "Provider": "P1",
        "DepartureDate": "2023-07-20T05:06:00",
        "TrainNumber": "255С",
        "OnlyFpkBranded": False,
        "SpecialPlacesDemand": "StandardPlacesAndForDisabledPersons"
    },
    headers = headers,
    cookies = cookies,
    allow_redirects = True,
    verify = False,
    timeout = 10,
)
# Out:
# d:\anaconda3\envs\traveler\Lib\site-packages\urllib3\connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ticket.rzd.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
res.json()
# Out:
# {'OriginCode': '2010001',
#  'DestinationCode': '2010280',
#  'OriginTimeZoneDifference': 0,
#  'DestinationTimeZoneDifference': 0,
#  'Cars': [{'DestinationStationCode': '2010280',
#    'CarType': 'Compartment',
#    'CarDirection': 'NoValue',
#    'RailwayCarSchemeId': None,
#    'CarSubType': '66К',
#    'CarTypeName': 'КУПЕ',
#    'CarSchemeName': '66К',
#    'CarNumber': '24',
#    'ServiceClass': '2У',
#    'ServiceClassNameRu': None,
#    'ServiceClassNameEn': None,
#    'InternationalServiceClass': '',
#    'CarDescription': 'Ж',
#    'ServiceClassTranscript': 'Кондиционер в вагоне. Наличие биотуалета не гарантировано. Белье входит в стоимость проезда.\nВагон с услугой перевозки животных.',
#    'FreePlaces': '10, 18, 20, 24, 32',
#    'FreePlacesByCompartments': [{'CompartmentNumber': '3', 'Places': '10'},
#     {'CompartmentNumber': '5', 'Places': '18, 20'},
#     {'CompartmentNumber': '6', 'Places': '24'},
#     {'CompartmentNumber': '8', 'Places': '32'}],
# ...

# %%
res = s.get(
    url = 'https://ticket.rzd.ru/api/v1/suggests',
    params = {
        'Query': 'ЯРОСЛАВЛЬ',
        'TransportType': 'bus,avia,rail,aeroexpress,suburban,boat',
        'GroupResults': True,
        'RailwaySortPriority': False,
        'SynonymOn': 1,
    },
    headers = headers,
    allow_redirects = True,
    cookies = cookies,
    timeout = 10,
    verify = False,
)
# Out:
# d:\anaconda3\envs\traveler\Lib\site-packages\urllib3\connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ticket.rzd.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
res.json()
# Out:
# {'city': [{'nodeId': '5a13bdcc340c745ca1e8ac90',
#    'expressCode': '2010000',
#    'name': 'Ярославль',
#    'nodeType': 'city',
#    'transportType': 'city',
#    'region': 'Ярославская Область, Российская Федерация',
#    'regionIso': 'RU-YAR',
#    'countryIso': 'RU',
#    'aviaCode': 'IAR',
#    'busCode': '5a13bdcc340c745ca1e8ac90',
#    'suburbanCode': '6630,6635',
#    'foreignCode': '2010000',
#    'expressCodes': '2010001,2010002,2010003,2010004,2010345,2010346,2010379,2011266,2011271,2011308',
#    'hasAeroExpress': False}],
#  'train': [{'nodeId': '5a8abf39340c742578d366b2',
#    'expressCode': '2010001',
#    'name': 'Ярославль-Главный',
#    'nodeType': 'station',
#    'transportType': 'train',
#    'region': 'Ярославль, Ярославская Область, Российская Федерация',
#    'regionIso': 'RU-YAR',
#    'countryIso': 'RU',
#    'suburbanCode': '6630',
#    'foreignCode': '2010001',
#    'hasAeroExpress': False},
#   {'nodeId': '5a8abf3b340c7425afd366a8',
# ...

# %%
import json
with open('../data/station_suggest_rzd.json', 'w', encoding='utf-8') as f:
    json.dump(res.json(), f, ensure_ascii=False)
